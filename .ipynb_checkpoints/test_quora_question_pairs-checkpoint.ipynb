# %% [markdown]
# ### tools

# %%
import quora_question_pairs as qqp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-447df7bf03c9> in <module>()
# ----> 1 import quora_question_pairs as qqp
#
# ImportError: No module named 'quora_question_pairs'

# %%
qqp.dif_length('abc', 'ab');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-645b703c3fc4> in <module>()
# ----> 1 qqp.dif_length('abc', 'ab');
#
# NameError: name 'qqp' is not defined
