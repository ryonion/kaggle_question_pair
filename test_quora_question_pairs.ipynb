# %% [markdown]
# ### tools

# %%
import quora_question_pairs as qqp

# %%
assert(qqp.dif_length('abc', 'ab') == 1)
assert(qqp.dif_length('abc', 'abc') == 0)
assert(qqp.dif_length('', '') == 0)
assert(qqp.dif_length('', 'abssss') == 6)
